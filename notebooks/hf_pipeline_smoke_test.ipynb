# %% [markdown]
# # HuggingFace pipeline smoke test (Colab)

# %%
# %cd /content
# !rm -rf mioti-mic-push-t
# !git clone https://github.com/mioti-mic/mioti-mic-push-t.git
# %cd mioti-mic-push-t

# %%
# !pip -q uninstall -y gym || true
# !pip -q install --upgrade pip
# !pip -q install -r requirements.txt # -c constraints.txt

# %%
from huggingface_hub import login, upload_folder
from google.colab import userdata


# (optional) Login with your Hugging Face credentials
login(token = userdata.get("HF_TOKEN"))

# Parte del ejemplo de HuggingFace, no usar, sube todo (queremos subir solo datos).
# upload_folder(
#     folder_path = ".",
#     repo_id = "mioti-mic/mioti-mic-push-t",
#     repo_type = "dataset"
# )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from huggingface_hub import login, upload_folder
#       2 from google.colab import userdata
#       5 # (optional) Login with your Hugging Face credentials
#
# ModuleNotFoundError: No module named 'huggingface_hub'

# %%
PYTHONPATH=$PYTHONPATH:$(pwd) python scripts/lerobot_dataset_sanity.py --repo-id lerobot/pusht --index 0

# %%
PYTHONPATH=$PYTHONPATH:$(pwd) python scripts/pusht_env_smoke_lerobot_runtime.py --horizon 50 --render
